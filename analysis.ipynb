# %% [markdown]
# # INSEE Data Analysis
#
# This notebook is set up for analyzing INSEE (Institut National de la Statistique et des Études Économiques) data.
#
# ## Getting Started
# - Run the cells below to import the necessary libraries
# - Load your INSEE data and begin analysis

# %%
# Import essential libraries for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set up plotting
plt.style.use('default')
sns.set_palette('husl')

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Configuration and settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Display versions
print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
# Out:
# pandas version: 2.3.2
# numpy version: 2.3.3

# %% [markdown]
# ## Data Loading
#
# Use the cell below to load your INSEE data:

# %%
# Load your INSEE data here
# Example:
face_raw = pd.read_csv('data/face_raw_salesforce_ready.csv')
face_raw.head()
# Out:
#   Organisation_Original Taille_Original        SIREN Denomination_INSEE  \
# 0               Abylsen             ETI  479973521.0            ABYLSEN
# 1         AdatechSchool             PME          NaN                NaN
# 2                ADECCO             PME  343009866.0    ADECCO TRAINING
# 3                 Adobe             PME  949079610.0              ADOBE
# 4            ADP Groupe              GE          NaN                NaN
#
#    Effectifs_Salesforce Effectifs_Description Confiance_Donnee  \
# 0                   NaN         Non renseigné              low
# 1                   NaN                   NaN              low
# 2                 150.0    100 à 199 salariés             high
# 3                   NaN         Non renseigné              low
# 4                   NaN                   NaN              low
#
#      Statut_Revision  Match_Score  \
# 0  MISSING_EFFECTIFS           90
# 1          NOT_FOUND           40
# 2          CONFIRMED          100
# 3  MISSING_EFFECTIFS           90
# 4          NOT_FOUND           40
#
#                                       Notes_Revision  Annee_Effectifs  \
# 0  ⚠️ Trouvée mais effectifs non renseignés - rec...              NaN
# 1  ❌ Entreprise non trouvée dans INSEE - vérifier...              NaN
# 2                    ✅ Données cohérentes et fiables           2022.0
# 3  ⚠️ Trouvée mais effectifs non renseignés - rec...              NaN
# 4  ❌ Entreprise non trouvée dans INSEE - vérifier...              NaN
#
#   Categorie_Entreprise_INSEE         SIRET Date_Creation Activite_Principale  \
# 0                        ETI  4.799735e+13    2004-12-07              71.12B
# 1                        NaN           NaN           NaN                 NaN
# 2                         GE  3.430099e+13    1987-10-05              85.59A
# 3                        NaN  9.490796e+13    2023-01-19              68.20B
# 4                        NaN           NaN           NaN                 NaN
#
#   Etat_Administratif  Nb_Etablissements Statut_Recherche  \
# 0                  A                3.0           Trouvé
# 1                NaN                NaN       Non trouvé
# 2                  A                3.0           Trouvé
# 3                  A                3.0           Trouvé
# 4                NaN                NaN       Non trouvé
#
#                Date_Recherche
# 0  2025-09-14T23:49:43.578937
# 1  2025-09-14T23:49:46.772276
# 2  2025-09-14T23:49:49.897988
# 3  2025-09-14T23:49:53.042618
# 4  2025-09-14T23:49:56.234226

# %%
# Load your INSEE data here
# Example:
demo = pd.read_csv('data/demo_10_optimized_salesforce_ready.csv')
demo.tail(150)
# Out:
#   Organisation_Original Taille_Original  Effectifs_Salesforce  \
# 0             3M FRANCE             ETI                   750
# 1             3M FRANCE              GE                   750
# 2             3M FRANCE              GE                   750
# 3             3M FRANCE              GE                   750
# 4          A.T.S. LASER           MICRO                   150
# 5             AB7 SANTE             PME                   150
# 6             AB7 SANTE             PME                   150
# 7       ABAX INDUSTRIES             PME                    35
# 8       ABAX INDUSTRIES             PME                    35
# 9                Abbvie              GE                   750
#
#   Effectifs_Description Confiance_Donnee Statut_Revision  Match_Score  \
# 0    500 à 999 salariés           medium       TO_REVIEW           40
# 1    500 à 999 salariés           medium       TO_REVIEW           40
# 2    500 à 999 salariés           medium       TO_REVIEW           40
# 3    500 à 999 salariés           medium       TO_REVIEW           40
# 4    100 à 199 salariés             high       TO_REVIEW           40
# 5    100 à 199 salariés             high       TO_REVIEW           40
# 6    100 à 199 salariés             high       TO_REVIEW           40
# 7      20 à 49 salariés             high       TO_REVIEW           40
# 8      20 à 49 salariés             high       TO_REVIEW           40
# 9    500 à 999 salariés           medium       TO_REVIEW           40
#
#                          Notes_Revision Statut_Recherche
# 0  📊 Tranche moyenne - bonne estimation        TO_REVIEW
# 1  📊 Tranche moyenne - bonne estimation        TO_REVIEW
# 2  📊 Tranche moyenne - bonne estimation        TO_REVIEW
# 3  📊 Tranche moyenne - bonne estimation        TO_REVIEW
# 4                           Aucune note        TO_REVIEW
# 5                           Aucune note        TO_REVIEW
# 6                           Aucune note        TO_REVIEW
# 7                           Aucune note        TO_REVIEW
# 8                           Aucune note        TO_REVIEW
# 9  📊 Tranche moyenne - bonne estimation        TO_REVIEW

# %%
# Diagnostic des problèmes de statut
demo = pd.read_csv('data/demo_10_optimized_salesforce_ready.csv')
raw = pd.read_csv('data/insee_optimized_demo_10_results.csv')

print("=== DIAGNOSTIC DES STATUTS ===")
print("\n1. Exemple 3M FRANCE:")
print(f"   Taille originale: {demo.iloc[0]['Taille_Original']}")
print(f"   Effectifs extraits: {demo.iloc[0]['Effectifs_Description']}")
print(f"   Confiance: {demo.iloc[0]['Confiance_Donnee']}")
print(f"   Statut: {demo.iloc[0]['Statut_Revision']}")

print(f"\n   INSEE - Tranche établissement: {raw.iloc[0]['tranche_effectifs_etablissement']}")
print(f"   INSEE - Tranche unité légale: {raw.iloc[0]['tranche_effectifs_unite_legale']}")
print(f"   INSEE - Catégorie entreprise: {raw.iloc[0]['categorie_entreprise']}")

print("\n2. Tous les statuts dans le demo:")
statut_counts = demo['Statut_Revision'].value_counts()
print(statut_counts)

print("\n3. Répartition par confiance:")
confiance_counts = demo['Confiance_Donnee'].value_counts()
print(confiance_counts)
# Out:
# === DIAGNOSTIC DES STATUTS ===
#
# 1. Exemple 3M FRANCE:
#    Taille originale: ETI
#    Effectifs extraits: 1000 à 1999 salariés
#    Confiance: medium
#    Statut: TO_REVIEW
#
#    INSEE - Tranche établissement: 41
#    INSEE - Tranche unité légale: 42
#    INSEE - Catégorie entreprise: ETI
#
# 2. Tous les statuts dans le demo:
# Statut_Revision
# TO_REVIEW    10
# Name: count, dtype: int64
#
# 3. Répartition par confiance:
# Confiance_Donnee
# medium    5
# high      5
# Name: count, dtype: int64
